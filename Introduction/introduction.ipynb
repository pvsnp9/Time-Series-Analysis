# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the data

# %%
raw_csv_data = pd.read_csv("./../datasets/Index2018.csv")

# %%
df =  raw_csv_data.copy()

# %% [markdown]
# ### Examine the data
#
# We usually use date as index for time series data. The rest of the four variables are market indexes - S&P 500 (spx) - USA, DAX 30 (dax) - GER, FTSE 100 (ftse) - UK, NIKKEI 225 (nikkei) - Japan.

# %%
df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
df.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# ### Plotting data
#
# This gives us the idea on how the data has developed over time.

# %%
df.spx.plot(figsize=(20,5),title="S&P 500 price")
plt.show()

# %% [markdown]
# In proper time-series, the x-axis would show the corresponding dates for each period. In the graph above, the starting time is 0, and ending is 6000+. Here, Each data points are plotted, rather than time basis due to its default index.

# %%
df.ftse.plot(figsize=(20,5),title="S&P 500 price")
df.spx.plot(figsize=(20,5),title="S&P 500 price")
plt.title("S&P vs FTSE")
plt.show()

# %% [markdown]
# We can see the similar trend in both charts. We can observe that the FTSE vlaues are much larger than S&P. In aadition, the S&P is much flatter than FTSE,which means S&P is more stable. But wiat, it is becuase of the magnitude of the price axis.

# %% [markdown]
# ### QQ Plot
#
# Used to examine whether a data set is distributed in a certain way, i.e normal distribution.

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df.spx, plot=pylab)
pylab.show()

# %% [markdown]
# Y axis represents the ordered proce, and X axis represents the theoritical quantiles; in anothe word, How many standard deviations away from the mean these vaules are. The red line - what the data points should follow, if they are normally distributed. Looking at the plot, it is not the case since the more values are arounf 500.
